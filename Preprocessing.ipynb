# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
file_name = 'data/application_clean.csv'
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Unnamed: 0  SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           0      100002       1         Cash loans           M            N
# 1           1      100003       0         Cash loans           F            N
# 2           2      100004       0    Revolving loans           M            Y
# 3           3      100006       0         Cash loans           F            N
# 4           4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0         202500.00   406597.50     24700.50
# 1               N             0         270000.00  1293502.50     35698.50
# 2               Y             0          67500.00   135000.00      6750.00
# 3               Y             0         135000.00   312682.50     29686.50
# 4               Y             0         121500.00   513000.00     21865.50
#
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0         202500.00   406597.50     24700.50
# 1               N             0         270000.00  1293502.50     35698.50
# 2               Y             0          67500.00   135000.00      6750.00
# 3               Y             0         135000.00   312682.50     29686.50
# 4               Y             0         121500.00   513000.00     21865.50
#
#    AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0        351000.00   Unaccompanied          Working
# ...

# %%
df.describe().T
# Out:
#                                 count      mean       std       min       25%  \
# SK_ID_CURR                  307511.00 278180.52 102790.18 100002.00 189145.50
# TARGET                      307511.00      0.08      0.27      0.00      0.00
# CNT_CHILDREN                307511.00      0.42      0.72      0.00      0.00
# AMT_INCOME_TOTAL            307511.00 168797.92 237123.15  25650.00 112500.00
# AMT_CREDIT                  307511.00 599026.00 402490.78  45000.00 270000.00
# AMT_ANNUITY                 307511.00  27108.57  14493.45   1615.50  16524.00
# AMT_GOODS_PRICE             307511.00 538316.29 369288.98  40500.00 238500.00
# REGION_POPULATION_RELATIVE  307511.00      0.02      0.01      0.00      0.01
# FLAG_MOBIL                  307511.00      1.00      0.00      0.00      1.00
# FLAG_EMP_PHONE              307511.00      0.82      0.38      0.00      1.00
# FLAG_WORK_PHONE             307511.00      0.20      0.40      0.00      0.00
# ...

# %%
dfo=df.select_dtypes(include=['object']) # select object type columns
#df = pd.concat([df.drop(dfo, axis=1), pd.get_dummies(dfo)], axis=1)
#dfo = pd.get_dummies(dfo)

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0         202500.00   406597.50     24700.50
# 1               N             0         270000.00  1293502.50     35698.50
# 2               Y             0          67500.00   135000.00      6750.00
# 3               Y             0         135000.00   312682.50     29686.50
# 4               Y             0         121500.00   513000.00     21865.50
#
#    AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0        351000.00   Unaccompanied          Working
# ...

# %%
dfo.head()
# Out:
#   NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY NAME_TYPE_SUITE  \
# 0         Cash loans           M            N               Y   Unaccompanied
# 1         Cash loans           F            N               N          Family
# 2    Revolving loans           M            Y               Y   Unaccompanied
# 3         Cash loans           F            N               Y   Unaccompanied
# 4         Cash loans           M            N               Y   Unaccompanied
#
#   NAME_INCOME_TYPE            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          Working  Secondary / secondary special             Single
# 1    State servant               Higher education            Married
# 2          Working  Secondary / secondary special             Single
# 3          Working  Secondary / secondary special     Civil marriage
# 4          Working  Secondary / secondary special             Single
#
#    NAME_HOUSING_TYPE OCCUPATION_TYPE WEEKDAY_APPR_PROCESS_START  \
# ...

# %%
df_s = df.drop(dfo, axis=1)

# %%
df_s.head()
# Out:
#    SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0      100002       1             0         202500.00   406597.50
# 1      100003       0             0         270000.00  1293502.50
# 2      100004       0             0          67500.00   135000.00
# 3      100006       0             0         135000.00   312682.50
# 4      100007       0             0         121500.00   513000.00
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  FLAG_MOBIL  \
# 0     24700.50        351000.00                        0.02           1
# 1     35698.50       1129500.00                        0.00           1
# 2      6750.00        135000.00                        0.01           1
# 3     29686.50        297000.00                        0.01           1
# 4     21865.50        513000.00                        0.03           1
#
#    FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  \
# ...

# %%
#drop flag columns since they don't need to be scaled
col = ['FLAG_MOBIL', 'FLAG_EMP_PHONE','FLAG_WORK_PHONE','FLAG_CONT_MOBILE', 'FLAG_PHONE','FLAG_EMAIL']
flags = df[col]
df_s = df_s.drop(col, axis=1)

# %%
df_s.head()
# Out:
#    SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0      100002       1             0         202500.00   406597.50
# 1      100003       0             0         270000.00  1293502.50
# 2      100004       0             0          67500.00   135000.00
# 3      100006       0             0         135000.00   312682.50
# 4      100007       0             0         121500.00   513000.00
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  CNT_FAM_MEMBERS  \
# 0     24700.50        351000.00                        0.02                1
# 1     35698.50       1129500.00                        0.00                2
# 2      6750.00        135000.00                        0.01                1
# 3     29686.50        297000.00                        0.01                2
# 4     21865.50        513000.00                        0.03                1
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  HOUR_APPR_PROCESS_START  \
# ...

# %%
SK_ID_CURR = df_s['SK_ID_CURR']

# %%
SK_ID_CURR.head()
# Out:
# 0    100002
# 1    100003
# 2    100004
# 3    100006
# 4    100007
# Name: SK_ID_CURR, dtype: int64

# %%
names = df_s.columns

# %%
from sklearn.preprocessing import MinMaxScaler

# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled = scaler.fit_transform(df_s)
print(scaled)
# Out:
# [[0.00000000e+00 1.00000000e+00 0.00000000e+00 ... 2.94416244e-01
#   2.62711864e-01 2.50000000e-01]
#  [2.80699391e-06 0.00000000e+00 0.00000000e+00 ... 4.06091371e-02
#   1.94915254e-01 2.50000000e-01]
#  [5.61398781e-06 0.00000000e+00 0.00000000e+00 ... 3.50253807e-01
#   1.86440678e-01 0.00000000e+00]
#  ...
#  [9.99994386e-01 0.00000000e+00 0.00000000e+00 ... 7.15736041e-01
#   4.40677966e-01 2.50000000e-01]
#  [9.99997193e-01 1.00000000e+00 0.00000000e+00 ... 1.31979695e-01
#   7.62711864e-02 2.50000000e-01]
#  [1.00000000e+00 0.00000000e+00 0.00000000e+00 ... 5.58375635e-02
#   1.86440678e-01 2.50000000e-01]]

# %%
df_scaled = pd.DataFrame(scaled, columns=names)

# %%
df_scaled.head()
# Out:
#    SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0        0.00    1.00          0.00              0.00        0.09
# 1        0.00    0.00          0.00              0.00        0.31
# 2        0.00    0.00          0.00              0.00        0.02
# 3        0.00    0.00          0.00              0.00        0.07
# 4        0.00    0.00          0.00              0.00        0.12
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  CNT_FAM_MEMBERS  \
# 0         0.09             0.08                        0.26             0.00
# 1         0.13             0.27                        0.05             0.05
# 2         0.02             0.02                        0.13             0.00
# 3         0.11             0.06                        0.11             0.05
# 4         0.08             0.12                        0.39             0.00
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  HOUR_APPR_PROCESS_START  \
# ...

# %%
df_scaled['SK_ID_CURR'] = SK_ID_CURR

# %%
dfo = pd.get_dummies(dfo)

# %%
dfo.head()
# Out:
#    NAME_CONTRACT_TYPE_Cash loans  NAME_CONTRACT_TYPE_Revolving loans  \
# 0                              1                                   0
# 1                              1                                   0
# 2                              0                                   1
# 3                              1                                   0
# 4                              1                                   0
#
#    CODE_GENDER_F  CODE_GENDER_M  CODE_GENDER_XNA  FLAG_OWN_CAR_N  \
# 0              0              1                0               1
# 1              1              0                0               1
# 2              0              1                0               0
# 3              1              0                0               1
# 4              0              1                0               1
#
#    FLAG_OWN_CAR_Y  FLAG_OWN_REALTY_N  FLAG_OWN_REALTY_Y  \
# 0               0                  0                  1
# ...

# %%
df_scaled = pd.concat([df_scaled, dfo], axis=1)
df_scaled.head()
# Out:
#    SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0      100002    1.00          0.00              0.00        0.09
# 1      100003    0.00          0.00              0.00        0.31
# 2      100004    0.00          0.00              0.00        0.02
# 3      100006    0.00          0.00              0.00        0.07
# 4      100007    0.00          0.00              0.00        0.12
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  CNT_FAM_MEMBERS  \
# 0         0.09             0.08                        0.26             0.00
# 1         0.13             0.27                        0.05             0.05
# 2         0.02             0.02                        0.13             0.00
# 3         0.11             0.06                        0.11             0.05
# 4         0.08             0.12                        0.39             0.00
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  HOUR_APPR_PROCESS_START  \
# ...

# %%
y = df_scaled['TARGET']

# %%
X = df_scaled.drop('TARGET', axis = 1)

# %%
X.head()
# Out:
#    SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0      100002          0.00              0.00        0.09         0.09
# 1      100003          0.00              0.00        0.31         0.13
# 2      100004          0.00              0.00        0.02         0.02
# 3      100006          0.00              0.00        0.07         0.11
# 4      100007          0.00              0.00        0.12         0.08
#
#    AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  CNT_FAM_MEMBERS  \
# 0             0.08                        0.26             0.00
# 1             0.27                        0.05             0.05
# 2             0.02                        0.13             0.00
# 3             0.06                        0.11             0.05
# 4             0.12                        0.39             0.00
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  HOUR_APPR_PROCESS_START  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
X_train.shape
# Out:
# (215257, 158)

# %%
X_test.shape
# Out:
# (92254, 158)
